# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Campaign Contribution Analysis of Greg Pence's campaign.

# %%
pence = pd.read_csv(r'C:\Users\spyle\Downloads\schedule_a-2020-12-12T14_28_48.csv')

# %%
del pence["committee_id"]

# %%
pence
# Out:
#        report_year entity_type_desc          contributor_name  \
# 0             2018       INDIVIDUAL     PENCE, GREGORY J. MR.
# 1             2018     ORGANIZATION         NOVA LIST COMPANY
# 2             2018       INDIVIDUAL      SCHALLER, ROGER L MR
# 3             2018       INDIVIDUAL       WEISER, ROBERT A MR
# 4             2018       INDIVIDUAL         DE JONG, PETER MR
# ...            ...              ...                       ...
# 11128         2019       INDIVIDUAL     NEWTON, PHILIP S. MR.
# 11129         2019       INDIVIDUAL       GRANT, RAYMOND E MR
# 11130         2019       INDIVIDUAL   WHIPKER, KENNETH J. MR.
# 11131         2019       INDIVIDUAL  WALLIEN, ROBERT ERIC MR.
# 11132         2019       INDIVIDUAL          THARP, ELIZABETH
#
#       contributor_first_name contributor_last_name       contributor_street_1  \
# 0                    GREGORY                 PENCE              482 S MUTZ DR
# ...

# %%
year_2017 = pence[pence['report_year']== 2017]

# %%
year_2017
# Out:
#       report_year            entity_type_desc  \
# 2285         2017                  INDIVIDUAL
# 2286         2017                  INDIVIDUAL
# 2341         2017  POLITICAL ACTION COMMITTEE
# 2342         2017  POLITICAL ACTION COMMITTEE
# 2343         2017  POLITICAL ACTION COMMITTEE
# ...           ...                         ...
# 2701         2017                  INDIVIDUAL
# 2702         2017                  INDIVIDUAL
# 2703         2017                  INDIVIDUAL
# 2704         2017                  INDIVIDUAL
# 2705         2017                  INDIVIDUAL
#
#                                        contributor_name  \
# 2285                              HILBERT, TOMISUE MRS.
# 2286                            HILBERT, STEPHEN C. MR.
# 2341                                              YOPAC
# 2342  BOSTON SCIENTIFIC CORPORATION POLITICAL ACTION...
# 2343                          AMERICA'S FUTURE FUND PAC
# ...                                                 ...
# ...

# %%
total_2017 = year_2017.contribution_receipt_amount.sum()
total_2017
# Out:
# 558981.6699999999

# %%
year_2018 = pence[pence['report_year'] == 2018]
total_2018 = year_2018.contribution_receipt_amount.sum()
total_2018
# Out:
# 1911148.1800000002

# %%
year_2019 = pence[pence['report_year'] == 2019]
total_2019 = year_2019.contribution_receipt_amount.sum()
total_2019
# Out:
# 987089.9899999999

# %%
year_2020 = pence[pence['report_year'] == 2020]
total_2020 = year_2020.contribution_receipt_amount.sum()
total_2020
# Out:
# 1050848.41

# %%
df = pd.DataFrame({'contribution_receipt_amount' : pence.groupby("contributor_employer")["contribution_receipt_amount"].sum()}).reset_index()

# %%
df
# Out:
#                        contributor_employer  contribution_receipt_amount
# 0                         1M SOLUTIONS, LLC                         85.0
# 1                   49 GAS ENTERPRISES INC.                       2100.0
# 2                             50 STATES LLC                       1000.0
# 3                        A-C-E WELDING INC.                        500.0
# 4                     A-REED EXCAVATING LLC                        250.0
# ..                                      ...                          ...
# 929  ZIEMER, STAYMAN, WEITZEL, SHOULDERS, L                       1000.0
# 930               ZINK DISTRIBUTION COMPANY                       2700.0
# 931                               ZLJS, LLC                       1000.0
# 932                          ZOTEC PARTNERS                       1000.0
# 933                      ZOTEC PARTNERS LLC                       2700.0
#
# [934 rows x 2 columns]

# %%
import seaborn as sns
ax = sns.barplot(x='contribution_receipt_amount', y='contributor_employer', data=df.sort_values('contribution_receipt_amount', ascending=False)[:15])
_ = ax.set(xlabel='Contribution Amount', ylabel='Contributor Employer', title = "Top 15 Contributions")

# %%
schwarzman = pence[pence['contributor_last_name'] == 'SCHWARZMAN']

# %%
schwarzman.contribution_receipt_amount.sum()
# Out:
# 22000.0

# %%
state = pd.DataFrame({'contribution_receipt_amount' : pence.groupby("contributor_state")["contribution_receipt_amount"].sum()}).reset_index()

# %%
state
# Out:
#    contributor_state  contribution_receipt_amount
# 0                 AK                      2251.69
# 1                 AL                      8952.76
# 2                 AR                     11197.80
# 3                 AZ                     75265.15
# 4                 CA                    189688.16
# 5                 CO                     40896.72
# 6                 CT                     31805.14
# 7                 DC                    334764.41
# 8                 DE                       911.11
# 9                 FL                    169840.06
# 10                GA                     40312.91
# 11                HI                      4027.68
# 12                IA                     18597.48
# 13                ID                      5577.43
# 14                IL                    144609.58
# 15                IN                   1844303.89
# 16                KS                     28620.61
# 17                KY                     11235.50
# ...

# %%
ax = sns.barplot(x='contribution_receipt_amount', y='contributor_state', data=state.sort_values('contribution_receipt_amount', ascending=False)[:15])
_ = ax.set(xlabel='Contribution Amount', ylabel='State', title = "Top 15 States")

# %%
state.contribution_receipt_amount.sum()
# Out:
# 4507565.319999998

# %%
percent = 1844303.89 / 4507565.319999998 * 100
percent
# Forty Percent of Greg Pence's Contributions came from Indiana
# Out:
# 40.91574406735387

# %%
dc = pence[pence['contributor_state'] == 'DC']
dc
# Out:
#        report_year            entity_type_desc  \
# 23            2018                  INDIVIDUAL
# 57            2018  POLITICAL ACTION COMMITTEE
# 58            2018  POLITICAL ACTION COMMITTEE
# 68            2018  POLITICAL ACTION COMMITTEE
# 71            2018  POLITICAL ACTION COMMITTEE
# ...            ...                         ...
# 10742         2019  POLITICAL ACTION COMMITTEE
# 10743         2019                  INDIVIDUAL
# 10910         2019                  INDIVIDUAL
# 10938         2019                  INDIVIDUAL
# 11000         2019                  INDIVIDUAL
#
#                                         contributor_name  \
# 23                                 FISHER, STEVEN A. MR.
# 57     ASSOCIATED BUILDERS AND CONTRACTORS POLITICAL ...
# 58              AMERICAN WIND ENERGY ASSOCIATION WINDPAC
# 68     UNITEDHEALTH GROUP INCORPORATED PAC (UNITEDHEA...
# 71              ERNST & YOUNG POLITICAL ACTION COMMITTEE
# ...

# %%
dc_contributors = state = pd.DataFrame({'contribution_receipt_amount' : dc.groupby("contributor_name")["contribution_receipt_amount"].sum()}).reset_index()

# %%
dc_contributors
# Out:
#                                       contributor_name  \
# 0                      AIR LINE PILOTS ASSOCIATION PAC
# 1    ALLIANCE OF AUTOMOBILE MANUFACTURERS INC POLIT...
# 2                                     ALPERT, NEIL MR.
# 3    ALTRIA GROUP, INC. POLITICAL ACTION COMMITTEE ...
# 4    AMERICAN BAKERS ASSOCIATION AMERICAN BAKERS PO...
# ..                                                 ...
# 98                         U.S. TRAVEL ASSOCIATION PAC
# 99   UNION PACIFIC CORP. FUND FOR EFFECTIVE GOVERNMENT
# 100  UNITEDHEALTH GROUP INCORPORATED PAC (UNITEDHEA...
# 101  VERIZON COMMUNICATIONS, INC. POLITICAL ACTION ...
# 102                                       WALL, JOSEPH
#
#      contribution_receipt_amount
# 0                         1000.0
# 1                         1000.0
# 2                         2000.0
# 3                        15000.0
# 4                         1000.0
# ..                           ...
# 98                        2500.0
# ...

# %%
ax = sns.barplot(x='contribution_receipt_amount', y='contributor_name', data=dc_contributors.sort_values('contribution_receipt_amount', ascending=False)[:15])
_ = ax.set(xlabel='Contribution Amount', ylabel='Contributors', title = "Top 15 Contributors From DC")

# %%
NY = pence[pence['contributor_state']== 'NY']
NY
# Out:
#        report_year entity_type_desc        contributor_name  \
# 3             2018       INDIVIDUAL     WEISER, ROBERT A MR
# 51            2018       INDIVIDUAL    DURLAND, ROBERT E SR
# 89            2018       INDIVIDUAL  GRANDINETTI, JOHN F MR
# 90            2018       INDIVIDUAL  FLORENTINO, GREGORY MR
# 138           2018       INDIVIDUAL      MARX, RICHARD C MR
# ...            ...              ...                     ...
# 11019         2019       INDIVIDUAL      MARX, RICHARD C MR
# 11026         2019       INDIVIDUAL   O'CONNELL, DERRY L MR
# 11043         2019       INDIVIDUAL             GROUT, ALAN
# 11076         2019       INDIVIDUAL           MURPHY, IRENE
# 11099         2019       INDIVIDUAL   O'CONNELL, DERRY L MR
#
#       contributor_first_name contributor_last_name contributor_street_1  \
# 3                     ROBERT                WEISER    107 COBLESKILL DR
# 51                    ROBERT               DURLAND   290 STONY BROOK RD
# ...

# %%
NY = pd.DataFrame({'contribution_receipt_amount' : NY.groupby("contributor_name")["contribution_receipt_amount"].sum()}).reset_index()
NY
# Out:
#             contributor_name  contribution_receipt_amount
# 0             ABDOW, BARBARA                         0.63
# 1                 AFIF, JUAN                         0.63
# 2          ALAMPI, JOSEPHINE                         1.25
# 3        ALLAHHAM, ALBIR MR.                      1000.00
# 4          ALPERT, AARON MR.                       250.00
# ..                       ...                          ...
# 267  WOOLLEY PARRY, VICTORIA                         0.62
# 268   YEPEZ, MARIANA C. MRS.                        70.00
# 269            ZABLE, ROBERT                      1000.00
# 270             ZAGARA, JOHN                        10.73
# 271     ZIRASCHI, ALEXANDRIA                         0.12
#
# [272 rows x 2 columns]

# %%
ax = sns.barplot(x='contribution_receipt_amount', y='contributor_name', data=NY.sort_values('contribution_receipt_amount', ascending=False)[:15])
_ = ax.set(xlabel='Contribution Amount', ylabel='Contributors', title = "Top 15 Contributors From NY")

# %%
# Stephen Schwarzman is the CEO of the Black Stone Group in New York worth $16 billion.
# Both Stephen and Christine Schwarzman have contributed over $22,000 to Greg Pence's campaign between 2016 and 2021.

# %%
joyce = pence[pence['contributor_last_name']=='JOYCE']
joyce = joyce[joyce['contributor_state']=='NY']
joyce
# Oil Executive for Otis Eastern Service Inc. 
# Contributed $8,316 to Grep Pence's Campaign
# Out:
#        report_year entity_type_desc       contributor_name  \
# 2425          2017       INDIVIDUAL  JOYCE, CHARLES P. MR.
# 2426          2017       INDIVIDUAL  JOYCE, CHARLES P. MR.
# 2427          2017       INDIVIDUAL  JOYCE, CHARLES P. MR.
# 10212         2019       INDIVIDUAL  JOYCE, CHARLES P. MR.
# 10213         2019       INDIVIDUAL  JOYCE, CHARLES P. MR.
#
#       contributor_first_name contributor_last_name contributor_street_1  \
# 2425                 CHARLES                 JOYCE           PO BOX 483
# 2426                 CHARLES                 JOYCE           PO BOX 483
# 2427                 CHARLES                 JOYCE           PO BOX 483
# 10212                CHARLES                 JOYCE           PO BOX 330
# 10213                CHARLES                 JOYCE           PO BOX 330
#
#       contributor_street_2 contributor_city contributor_state  \
# 2425                   NaN       WELLSVILLE                NY
# ...

# %%
joyce.contribution_receipt_amount.sum()
# Out:
# 8316.98

# %%
catsimatidis = pence[pence['contributor_last_name']=='CATSIMATIDIS']
catsimatidis = catsimatidis[catsimatidis['contributor_state']=='NY']
catsimatidis = catsimatidis[catsimatidis['contributor_first_name'] == 'JOHN']
catsimatidis
# Out:
#        report_year entity_type_desc               contributor_name  \
# 1724          2018       INDIVIDUAL  CATSIMATIDIS, JOHN A. MR. JR.
# 1725          2018       INDIVIDUAL         CATSIMATIDIS, JOHN MR.
# 2409          2017       INDIVIDUAL         CATSIMATIDIS, JOHN MR.
# 2410          2017       INDIVIDUAL         CATSIMATIDIS, JOHN MR.
# 10499         2019       INDIVIDUAL         CATSIMATIDIS, JOHN MR.
# 10500         2019       INDIVIDUAL         CATSIMATIDIS, JOHN MR.
#
#       contributor_first_name contributor_last_name contributor_street_1  \
# 1724                    JOHN          CATSIMATIDIS         817  5TH AVE
# 1725                    JOHN          CATSIMATIDIS         817  5TH AVE
# 2409                    JOHN          CATSIMATIDIS         817  5TH AVE
# 2410                    JOHN          CATSIMATIDIS         817  5TH AVE
# 10499                   JOHN          CATSIMATIDIS         817  5TH AVE
# ...

# %%
catsimatidis = pence[pence['contributor_last_name']=='CATSIMATIDIS']
catsimatidis = catsimatidis[catsimatidis['contributor_state']=='NY']
catsimatidis = catsimatidis[catsimatidis['contributor_first_name'] == 'MARGO']
catsimatidis
# Out:
#       report_year entity_type_desc          contributor_name  \
# 1723         2018       INDIVIDUAL  CATSIMATIDIS, MARGO MRS.
# 2408         2017       INDIVIDUAL  CATSIMATIDIS, MARGO MRS.
#
#      contributor_first_name contributor_last_name contributor_street_1  \
# 1723                  MARGO          CATSIMATIDIS         817  5TH AVE
# 2408                  MARGO          CATSIMATIDIS         817  5TH AVE
#
#      contributor_street_2 contributor_city contributor_state  contributor_zip  \
# 1723                FL 14         NEW YORK                NY          10065.0
# 2408                FL 14         NEW YORK                NY          10065.0
#
#      contributor_employer contributor_occupation  contribution_receipt_amount
# 1723      RED APPLE GROUP              EXECUTIVE                       2700.0
# 2408      RED APPLE GROUP              EXECUTIVE                       2700.0

# %%
catsimatidis.contribution_receipt_amount.sum()
# Out:
# 5400.0

# %%
catsimatidis.contribution_receipt_amount.sum()
# Out:
# 13500.0

# %%
# John Catsimatidis is the CEO of the United Refining Company.
# He is worth $2.8 billion

# %%
CA = pence[pence['contributor_state']=='CA']
CA = pd.DataFrame({'contribution_receipt_amount' : CA.groupby("contributor_name")["contribution_receipt_amount"].sum()}).reset_index()
ax = sns.barplot(x='contribution_receipt_amount', y='contributor_name', data=CA.sort_values('contribution_receipt_amount', ascending=False)[:15])
_ = ax.set(xlabel='Contribution Amount', ylabel='Contributors', title = "Top 15 Contributors From CA")

# %%
# Charles R Schwab is the founder of Charles Schwab and is worth $8.8billion
schwab = pence[pence['contributor_last_name']=='SCHWAB']
schwab = schwab[schwab['contributor_state'] == 'CA']
schwab
# Out:
#       report_year entity_type_desc     contributor_name  \
# 2043         2018       INDIVIDUAL  SCHWAB, CHARLES MR.
# 2044         2018       INDIVIDUAL  SCHWAB, CHARLES MR.
# 2045         2018       INDIVIDUAL  SCHWAB, CHARLES MR.
# 2852         2020       INDIVIDUAL  SCHWAB, CHARLES MR.
#
#      contributor_first_name contributor_last_name contributor_street_1  \
# 2043                CHARLES                SCHWAB       PO BOX  192861
# 2044                CHARLES                SCHWAB       PO BOX  192861
# 2045                CHARLES                SCHWAB       PO BOX  192861
# 2852                CHARLES                SCHWAB        PO BOX 192861
#
#      contributor_street_2 contributor_city contributor_state  contributor_zip  \
# 2043                  NaN    SAN FRANCISCO                CA          94119.0
# 2044                  NaN    SAN FRANCISCO                CA          94119.0
# 2045                  NaN    SAN FRANCISCO                CA          94119.0
# ...

# %%
schwab.contribution_receipt_amount.sum()
# Out:
# 8200.0

# %%
VA = pence[pence['contributor_state']=='VA']
VA = pd.DataFrame({'contribution_receipt_amount' : VA.groupby("contributor_name")["contribution_receipt_amount"].sum()}).reset_index()
ax = sns.barplot(x='contribution_receipt_amount', y='contributor_name', data=VA.sort_values('contribution_receipt_amount', ascending=False)[:15])
_ = ax.set(xlabel='Contribution Amount', ylabel='Contributors', title = "Top 15 Contributors From VA")

# %%
TX = pence[pence['contributor_state']=='TX']
TX = pd.DataFrame({'contribution_receipt_amount' : TX.groupby("contributor_name")["contribution_receipt_amount"].sum()}).reset_index()
ax = sns.barplot(x='contribution_receipt_amount', y='contributor_name', data=TX.sort_values('contribution_receipt_amount', ascending=False)[:15])
_ = ax.set(xlabel='Contribution Amount', ylabel='Contributors', title = "Top 15 Contributors From TX")

# %%
# Doug Deason is the son of Investor Darwin Deason.
# Doug Deason is worth over $500 million and contributed $5,500.
# Darwin Deason who is worth $1.3billion contributed $2700. 
deason = pence[pence['contributor_last_name']=='DEASON']
deason
# Out:
#        report_year entity_type_desc    contributor_name  \
# 2374          2017       INDIVIDUAL        DEASON, DOUG
# 2375          2017       INDIVIDUAL  DEASON, DARWIN MR.
# 10190         2019       INDIVIDUAL        DEASON, DOUG
#
#       contributor_first_name contributor_last_name      contributor_street_1  \
# 2374                    DOUG                DEASON           10134 WALLER DR
# 2375                  DARWIN                DEASON  5956 SHERRY LN. STE. 800
# 10190                   DOUG                DEASON           10134 WALLER DR
#
#       contributor_street_2 contributor_city contributor_state  \
# 2374                   NaN           DALLAS                TX
# 2375                   NaN           DALLAS                TX
# 10190                  NaN           DALLAS                TX
#
#        contributor_zip     contributor_employer       contributor_occupation  \
# 2374           75229.0            SELF EMPLOYED  FINANCE/INVESTMENTS/BANKING
# ...

# %%
executive = pence[pence['contributor_occupation']=='EXECUTIVE']
executive
# Out:
#        report_year entity_type_desc        contributor_name  \
# 0             2018       INDIVIDUAL   PENCE, GREGORY J. MR.
# 19            2018       INDIVIDUAL         MAUDLIN, LAURIE
# 22            2018       INDIVIDUAL  HEDGECOCK, RICHARD MR.
# 29            2018       INDIVIDUAL    RITTMAN, KENNETH MR.
# 59            2018       INDIVIDUAL       POPP, JOHN F. MR.
# ...            ...              ...                     ...
# 11106         2019       INDIVIDUAL       KUNKLE, CRAIG MR.
# 11111         2019       INDIVIDUAL     SPONSEL, DENNIS MR.
# 11121         2019       INDIVIDUAL       DEATON, LISA MRS.
# 11123         2019       INDIVIDUAL      ABINGTON, BILL MR.
# 11132         2019       INDIVIDUAL        THARP, ELIZABETH
#
#       contributor_first_name contributor_last_name  \
# 0                    GREGORY                 PENCE
# 19                    LAURIE               MAUDLIN
# 22                   RICHARD             HEDGECOCK
# ...

# %%
executive = pd.DataFrame({'contribution_receipt_amount' : executive.groupby("contributor_name")["contribution_receipt_amount"].sum()}).reset_index()
ax = sns.barplot(x='contribution_receipt_amount', y='contributor_name', data=executive.sort_values('contribution_receipt_amount', ascending=False)[:15])
_ = ax.set(xlabel='Contribution Amount', ylabel='Contributors', title = "Top 15 Contributors From Executives")

# %%
# Faith Ozmen is the owner and CEO of the Sierra Nevada Corporation.
# Ozmen is worth $1.2billion. Him and his wife Eren have donated $17,600.
ozmen = pence[pence['contributor_last_name']=='OZMEN']
ozmen.contribution_receipt_amount.sum()
# Out:
# 17600.0
